# %% [markdown]
# <a href="https://colab.research.google.com/github/swiminthewind/colab/blob/main/231127-5dNDVI%20time%20series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from seaborn import kdeplot
import numpy as np

# %%
datA = pd.read_excel("/content/drive/MyDrive/bzqx/rice_NDVI.xlsx")

# %%
std_x = []

# %%
VI = datA["0_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["1_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["2_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["3_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["4_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["5_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["6_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["7_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["8_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["9_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["10_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["11_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["12_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["13_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["14_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["15_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["16_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["17_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["18_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["19_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["20_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["21_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["22_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["23_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["24_NDVI"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
max_values_subset = datA.iloc[:, 3:].max()
max_values_list = max_values_subset.tolist()

# %%
min_values_subset = datA.iloc[:, 3:].min()
min_values_list = min_values_subset.tolist()

# %%
result_list = np.subtract(min_values_list, max_values_list)

# %%
std_values = ' '.join(map(str, std_x))
print(std_values)
max_values = ' '.join(map(str, max_values_list))
print(max_values)
sub_values = ' '.join(map(str, result_list))
print(sub_values)
# Out:
# 0.45408439542147405 0.4624016258713267 0.47624063519781357 0.4963363322604133 0.5196583263271863 0.5508194103879601 0.5835784474284796 0.6142131510802931 0.6381065754662467 0.6568685856521677 0.6774556679586294 0.6995700380278744 0.7167432619252085 0.7381374081376716 0.752795939384738 0.7521399448912364 0.7523302344841045 0.7561982716143718 0.7565229500565858 0.7612578906903069 0.7466569406665683 0.7171885689280894 0.6987917505442889 0.6766139971566607 0.6562923738773638
# 0.774019135339286 0.769390102374089 0.78394584255532 0.800938216676732 0.815296320322997 0.826634817115387 0.834646195998942 0.843167525531288 0.853443022162306 0.859615027600582 0.860835006702469 0.862042554357991 0.866888577975996 0.880860503088766 0.890896862145919 0.896463900679752 0.915435519064086 0.939977692567397 0.959563958297434 0.978924135886105 1.00019296371172 1.01581695420239 1.02504577790283 1.02728511337128 1.02211214992576
# ...
