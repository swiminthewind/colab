# %% [markdown]
# <a href="https://colab.research.google.com/github/swiminthewind/colab/blob/main/231208-5dNDRE%20time%20series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from seaborn import kdeplot
import numpy as np

# %%
datA = pd.read_excel("/content/drive/MyDrive/bzqx/fieldboundry_NDRE.xlsx")

# %%
std_x = []

# %%
VI = datA["0_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["1_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["2_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["3_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["4_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["5_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["6_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["7_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["8_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["9_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["10_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["11_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["12_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["13_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["14_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["15_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["16_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["17_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["18_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["19_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["20_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["21_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["22_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["23_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
VI = datA["24_NDRE"]
kde = kdeplot(VI, bw_method='silverman')
line = kde.lines[0]
x, y = line.get_data()
index = np.array(np.where(y==max(y)))
std_x.append(float(x[index]))

# %%
max_values_subset = datA.iloc[:, 3:].max()
max_values_list = max_values_subset.tolist()

# %%
min_values_subset = datA.iloc[:, 3:].min()
min_values_list = min_values_subset.tolist()

# %%
result_list = np.subtract(min_values_list, max_values_list)

# %%
std_values = ' '.join(map(str, std_x))
print(std_values)
max_values = ' '.join(map(str, max_values_list))
print(max_values)
sub_values = ' '.join(map(str, result_list))
print(sub_values)
# Out:
# 0.24267621159675157 0.24574696512250055 0.2536560110027848 0.26598315068924494 0.2739033926795175 0.28821127250789935 0.2978618831905912 0.31024467096657493 0.32162034242533255 0.339483151489709 0.3600347622179274 0.37416789909823456 0.3920786480550141 0.4067561828999832 0.42987784968325504 0.44913687376159256 0.4600749022809897 0.4663995839769407 0.47164401395247424 0.47172149039418293 0.47177231127602703 0.47007738079779415 0.46466584092905194 0.45067435697014846 0.43050748933173605
# 0.503898481243947 0.525110746958529 0.544239870890541 0.561049281942486 0.575365347529447 0.587080514295347 0.596154553773183 0.602612834183535 0.606544333654117 0.608096289848559 0.607468306795785 0.623761651194133 0.6470036721807 0.663289236955713 0.672176352884053 0.67342068678396 0.666982897214671 0.653029636942267 0.631928914900766 0.604239665602669 0.600223203198202 0.593314413735347 0.596473439226328 0.607375955292494 0.61308736136785
# -0.48171477093694476 -0.4813873647392888 -0.4755482445173653 -0.47092517847889304 -0.4819827596562216 -0.49026925920030373 -0.4957572245039731 -0.49847710734193695 -0.498514468311816 -0.496006558769414 -0.491137042396697 -0.5029861622080729 -0.521557691181915 -0.532921604353278 -0.536611035350999 -0.532359778307002 -0.5201101582079659 -0.500016899829164 -0.47244359468605596 -0.43795316981590093 -0.426821436211492 -0.412508626557871 -0.408011092818821 -0.41105285345826204 -0.40875826643851504
